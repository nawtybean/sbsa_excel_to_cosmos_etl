# %%
# import all the various libraries
# test 016
import json
import os

# %%
dataDict = {'alert': {'id': '016_test', 'Name': 'CIRCULAR 14', 'WebsiteName': 'https://www.fsca.co.za/Regulatory%20Frameworks/Pages/Circulars.aspx', 'DateExtracted': '2021-11-04T20:28:47.9270861Z', 'Jurisdiction': 'South Africa', 'Regulator': 'Financial Sector Conduct Authority', 'PageName': 'Circulars', 'PublicationDate': 'None', 'Description': 'Compulsory specifications for hot water storage tanks (geysers) will be enforced to reduce electricity consumption in the country. To ensure effective regulation, the National Regulator for Compulsory Specifications has developed an enforcement plan which include among others, inspections, stakeholder engagements, consumer awareness and surprise raids in various business premises.', 'DocumentURL': 'https://www.fsca.co.za/Regulatory%20Frameworks/Temp/CIRCULAR%2014.pdf', 'BlobStorageURL': '2021-11-04T20-28-47_CIRCULAR 14_42.pdf', 'Status': 5, 'FileHash': '5BE9698815FCA13D650215E0EEE80BFA3D277D59C156DAB131D4FA55AC55ABC0', 'AlertSourceId': '2082a64b-4586-4d7d-9010-8904eeeeaecb', 'RTAReviewRequired': False, 'AlertFlagReason': 'None', 'OriginalText': 'None', 'CleanedText': 'None', 'TokenizedText': 'None', 'DocFilename': 'None', 'CosineSimilarityScore': 'None', 'SoftCosineSimilarityScore': 'None', 'CosineFilenameSimilarTo': 'None', 'SoftCosineFilenameSimilarTo': 'None', 'Materiality': True, 'Applicability': True, 'Specialist': 'None', 'AAProcessUsed': 'None', 'IAProcessUsed': 'None', 'Assignees': [], 'DuplicateAlert': '00000000-0000-0000-0000-000000000000', 'UserId': '00000000-0000-0000-0000-000000000000', 'AgeStatus': 'None', 'LastUpdatedDate': '2021-11-29T11:49:46', 'LastUpdatedUserId': 'f002f502-dd7e-4af5-b2cd-49473ef59358', 'ApplicabilityChangeDate': '2021-11-12T06:27:50.919Z', 'ApplicabilityChangeJustification': 'Just 1', 'MaterialityChangeJustification': 'Just 2', 'MaterialityChangeDate': '2021-11-12T06:27:50.919Z', 'MaterialityCommentaryClosure': 0, 'MaterialityCommentaryClosureDate': '2021-11-14T22:00:00Z', 'MaterialityCommentClosure': 'nan', 'MaterialityCommentClosureDate': 'nan', '_rid': 'FJRLAJvRb6rcBAAAAAAAAA==', '_self': 'dbs/FJRLAA==/colls/FJRLAJvRb6o=/docs/FJRLAJvRb6rcBAAAAAAAAA==/', '_etag': '"00000000-0000-0000-e510-548ae94a01d7"', '_attachments': 'attachments/', '_ts': 1638183633}, 'filter': [('national road traffic regulations', 'LAW'), ('cargo reporters', 'ORG'), ('the national small enterprise act', 'LAW'), ('crime statistics', 'WORK_OF_ART'), ('liquor bill', 'LAW'), ('boradcasters', 'ORG'), ('political party funding bill', 'LAW'), ('planning profession act', 'LAW'), ('service charter', 'LAW'), ('framework bill', 'LAW'), ('the public finance management act', 'LAW'), ('the communications regulatory authority', 'ORG'), ('the namibia revenue agency act', 'LAW'), ('the communicaitons act', 'LAW'), ('investment promotion act', 'LAW'), ('namibia time act', 'LAW'), ('the namibia special risks insurance association act', 'LAW'), ('the law society', 'ORG'), ('the namibian medical aids fund', 'LAW'), ('bank of mozabique advisory council', 'ORG'), ('customs tariff', 'LAW'), ('the lesotho citizenship amendment of schedule regulations', 'ORG'), ('land commision act', 'LAW'), ('public health bill', 'LAW'), ('public health act', 'LAW'), ('labour court rules', 'LAW'), ('zimbabwe public procurement and disposal of public assets', 'LAW'), ('diamond cutting act', 'LAW'), ('diamond cutting bill', 'LAW'), ('the precious and semi-precious stones protection act', 'LAW'), ('the precious and semi-precious stones protection bill', 'LAW'), ('the national registration amendment bill', 'LAW'), ('the national registration amendment act', 'LAW'), ('the plant protection act', 'LAW'), ('the plant protection bill', 'LAW'), ('electricity company', 'ORG'), ('the industrial property law', 'LAW'), ('private security companies', 'ORG'), ('the general law on archives', 'LAW'), ('national flag act', 'LAW'), ('national flag amendment act', 'LAW'), ('copyright amendment act', 'LAW'), ('copyright act', 'LAW'), ('the mauritius allied health professionals coucil act', 'LAW'), ('development and classification of film act', 'ORG'), ('the tabacco control regulations', 'LAW'), ('namibian time act', 'LAW'), ('diamond cutting amendment act', 'LAW'), ('diamond cutting amendment bill', 'LAW'), ('the precious and semi-precious stones protection amendment act', 'LAW'), ('the precious and semi-precious stones protection amendment bill', 'LAW'), ('Public Finance Management Act', 'LAW'), ('The Lesotho Citizenship (Amendment of Schedule) Regulations', 'ORG'), ('Diamond Cutting (Amendment) Bill', 'LAW'), ('The Precious and Semi-Precious Stones Protection (Amendment) Bill', 'LAW'), ('The National Registration (Amendment) Bill', 'LAW'), ('National Flag (Amendment) Bill', 'LAW'), ('National Flag (Amendment) Act', 'LAW'), ('Copyright (Amendment) Bill', 'LAW'), ("Moody's Investors Service", 'ORG'), ('the Industrial Property Law', 'LAW'), ('Private Sercurity Companies', 'ORG')]}

# %%
import logging
from typing import Dict
from spacy.matcher import PhraseMatcher
import spacy
import en_core_web_sm

filter_data = {
    "id": "1",
    "filter": "Filter 1",
    "table": "AA_Filter_NER",
    "columns": ["Noun_Entity_Ruler", "Noun_Entity_Ruler_Label"]
}


def alert016(dataDict):
    alert = dataDict["alert"]
    filter_values = dataDict["filter"]
    logging.info(f'Performing {filter_data["filter"]} on {alert["id"]}')
    nlp = en_core_web_sm.load()
    description = alert["Description"]

    if description == "" or description == None  or description == "None":
        return "No"
    else:
        lang_doc = nlp(description)

        for ent in lang_doc.ents:
            print(ent.text.lower(), ent.label_.lower())
            print('---------------------')
            for noun_entity_ruler, noun_entity_ruler_label in filter_values:
                print(noun_entity_ruler, noun_entity_ruler_label)
                if ent.text.lower() == noun_entity_ruler.lower() and ent.label_.lower() == noun_entity_ruler_label.lower():
                    return "No"

        return "Yes"

# %%
result = alert016(dataDict)
result
# Out:
# the national regulator for compulsory specifications org
# ---------------------
# national road traffic regulations LAW
# cargo reporters ORG
# 'No'

# %%
dataDict = {'alert': {'id': '017_test', 'Name': 'Circular 29. SLA for Hedge Funds Managers', 'WebsiteName': 'https://www.fsca.co.za/Regulatory%20Frameworks/Pages/Circulars.aspx', 'DateExtracted': '2021-11-04T20:29:01.3542674Z', 'Jurisdiction': 'South Africa', 'Regulator': 'Financial Sector Conduct Authority', 'PageName': 'Circulars', 'PublicationDate': 'None', 'Description': 'Final rules have been published for the legal profession as required by the Legal Practice Act, 2014. Every legal practitioner who is admitted and enrolled as a legal practitioner must pay an annual fee to the South African Legal Practice Council: R2500 in the case of a legal practitioner who is in practice, and R800 in the case of a legal practitioner who is not in practice.', 'DocumentURL': 'https://www.fsca.co.za/Regulatory%20Frameworks/Temp/Circular%2029.%20SLA%20for%20Hedge%20Funds%20Managers.pdf', 'BlobStorageURL': '2021-11-04T20-29-00_Circular 29. SLA for Hedge Funds Managers_54.pdf', 'Status': 5, 'FileHash': '3CFD9780B86BF1F2335B147CEAD4BA4179E028F0CF37E643C44A871F9A6C0E70', 'AlertSourceId': '2082a64b-4586-4d7d-9010-8904eeeeaecb', 'RTAReviewRequired': False, 'AlertFlagReason': 'None', 'OriginalText': 'None', 'CleanedText': 'None', 'TokenizedText': 'None', 'DocFilename': 'None', 'CosineSimilarityScore': 'None', 'SoftCosineSimilarityScore': 'None', 'CosineFilenameSimilarTo': 'None', 'SoftCosineFilenameSimilarTo': 'None', 'Materiality': True, 'Applicability': True, 'Specialist': 'None', 'AAProcessUsed': 'None', 'IAProcessUsed': 'None', 'Assignees': ['asdfaa'], 'DuplicateAlert': '00000000-0000-0000-0000-000000000000', 'UserId': '00000000-0000-0000-0000-000000000000', 'AgeStatus': 'None', 'LastUpdatedDate': '2021-11-29T11:49:50', 'LastUpdatedUserId': 'f002f502-dd7e-4af5-b2cd-49473ef59358', 'ApplicabilityChangeDate': '2021-11-10T13:36:02.348Z', 'ApplicabilityChangeJustification': 'adfaa', 'MaterialityChangeJustification': 'adsfaa', 'MaterialityChangeDate': '2021-11-10T13:36:02.348Z', 'MaterialityCommentaryClosure': 'nan', 'MaterialityCommentaryClosureDate': 'nan', 'MaterialityCommentClosure': 'nan', 'MaterialityCommentClosureDate': 'nan', '_rid': 'FJRLAJvRb6rdBAAAAAAAAA==', '_self': 'dbs/FJRLAA==/colls/FJRLAJvRb6o=/docs/FJRLAJvRb6rdBAAAAAAAAA==/', '_etag': '"00000000-0000-0000-e519-cc0a16f601d7"', '_attachments': 'attachments/', '_ts': 1638187699}, 'filter': [('national road traffic regulations', 'LAW'), ('cargo reporters', 'ORG'), ('the national small enterprise act', 'LAW'), ('crime statistics', 'WORK_OF_ART'), ('liquor bill', 'LAW'), ('boradcasters', 'ORG'), ('political party funding bill', 'LAW'), ('planning profession act', 'LAW'), ('service charter', 'LAW'), ('framework bill', 'LAW'), ('the public finance management act', 'LAW'), ('the communications regulatory authority', 'ORG'), ('the namibia revenue agency act', 'LAW'), ('the communicaitons act', 'LAW'), ('investment promotion act', 'LAW'), ('namibia time act', 'LAW'), ('the namibia special risks insurance association act', 'LAW'), ('the law society', 'ORG'), ('the namibian medical aids fund', 'LAW'), ('bank of mozabique advisory council', 'ORG'), ('customs tariff', 'LAW'), ('the lesotho citizenship amendment of schedule regulations', 'ORG'), ('land commision act', 'LAW'), ('public health bill', 'LAW'), ('public health act', 'LAW'), ('labour court rules', 'LAW'), ('zimbabwe public procurement and disposal of public assets', 'LAW'), ('diamond cutting act', 'LAW'), ('diamond cutting bill', 'LAW'), ('the precious and semi-precious stones protection act', 'LAW'), ('the precious and semi-precious stones protection bill', 'LAW'), ('the national registration amendment bill', 'LAW'), ('the national registration amendment act', 'LAW'), ('the plant protection act', 'LAW'), ('the plant protection bill', 'LAW'), ('electricity company', 'ORG'), ('the industrial property law', 'LAW'), ('private security companies', 'ORG'), ('the general law on archives', 'LAW'), ('national flag act', 'LAW'), ('national flag amendment act', 'LAW'), ('copyright amendment act', 'LAW'), ('copyright act', 'LAW'), ('the mauritius allied health professionals coucil act', 'LAW'), ('development and classification of film act', 'ORG'), ('the tabacco control regulations', 'LAW'), ('namibian time act', 'LAW'), ('diamond cutting amendment act', 'LAW'), ('diamond cutting amendment bill', 'LAW'), ('the precious and semi-precious stones protection amendment act', 'LAW'), ('the precious and semi-precious stones protection amendment bill', 'LAW'), ('Public Finance Management Act', 'LAW'), ('The Lesotho Citizenship (Amendment of Schedule) Regulations', 'ORG'), ('Diamond Cutting (Amendment) Bill', 'LAW'), ('The Precious and Semi-Precious Stones Protection (Amendment) Bill', 'LAW'), ('The National Registration (Amendment) Bill', 'LAW'), ('National Flag (Amendment) Bill', 'LAW'), ('National Flag (Amendment) Act', 'LAW'), ('Copyright (Amendment) Bill', 'LAW'), ("Moody's Investors Service", 'ORG'), ('the Industrial Property Law', 'LAW'), ('Private Sercurity Companies', 'ORG')]}

# %%
filter_data = {
    "id": "1",
    "filter": "Filter 1",
    "table": "AA_Filter_NER",
    "columns": ["Noun_Entity_Ruler", "Noun_Entity_Ruler_Label"]
}


def alert017(dataDict):
    alert = dataDict["alert"]
    filter_values = dataDict["filter"]
    logging.info(f'Performing {filter_data["filter"]} on {alert["id"]}')
    nlp = en_core_web_sm.load()
    description = alert["Description"]

    if description == "" or description == None  or description == "None":
        return "No"
    else:
        lang_doc = nlp(description)

        for ent in lang_doc.ents:
            print(ent.text.lower(), ent.label_.lower())
            print('---------------------')
            for noun_entity_ruler, noun_entity_ruler_label in filter_values:
                print(noun_entity_ruler, noun_entity_ruler_label)
                if ent.text.lower() == noun_entity_ruler.lower() and ent.label_.lower() == noun_entity_ruler_label.lower():
                    return "No"

        return "Yes"

# %%
result = alert017(dataDict)
result
# Out:
# the legal practice act org
# ---------------------
# national road traffic regulations LAW
# cargo reporters ORG
# the national small enterprise act LAW
# crime statistics WORK_OF_ART
# liquor bill LAW
# boradcasters ORG
# political party funding bill LAW
# planning profession act LAW
# service charter LAW
# framework bill LAW
# the public finance management act LAW
# the communications regulatory authority ORG
# the namibia revenue agency act LAW
# the communicaitons act LAW
# investment promotion act LAW
# namibia time act LAW
# the namibia special risks insurance association act LAW
# the law society ORG
# the namibian medical aids fund LAW
# bank of mozabique advisory council ORG
# customs tariff LAW
# the lesotho citizenship amendment of schedule regulations ORG
# land commision act LAW
# public health bill LAW
# public health act LAW
# labour court rules LAW
# zimbabwe public procurement and disposal of public assets LAW
# diamond cutting act LAW
# diamond cutting bill LAW
# ...
